# %%
source("https://raw.githubusercontent.com/balthapaixao/Covid19_BR_underreport/master/Func_/new_preproc.R")
# Out:
# Using ',' as decimal and '.' as grouping mark. Use read_delim() for more control.

# %% [markdown]
# # Generating the data

# %%
X <- srag
data <- pre_proc_data(X, "graph")
# Out:
# Using ',' as decimal and '.' as grouping mark. Use read_delim() for more control.
#
# Warning message:
# “Missing column names filled in: 'X1' [1]”
# Parsed with column specification:
# cols(
#   X1 = col_double(),
#   Sigla = col_character(),
#   Codigo = col_double(),
#   Estado = col_character()
# )
#
# Using ',' as decimal and '.' as grouping mark. Use read_delim() for more control.
#
# Warning message:
# “Missing column names filled in: 'X1' [1]”
# Parsed with column specification:
# cols(
#   X1 = col_double(),
#   Sigla = col_character(),
#   Codigo = col_double(),
#   Estado = col_character()
# )

# %%
serie <- data$cases$no_covid
serie_deaths <- data$deaths$no_covid

# %%
state = "MG" # change this variable for whether state you prefer

# %%
#Plotting for cases
plot_srag(serie, state)
# Out:
# Warning message:
# “Removed 5 row(s) containing missing values (geom_path).”
# plot without title

# %%
#Plotting for deaths
plot_srag(serie_deaths, state)
# Out:
# Warning message:
# “Removed 5 row(s) containing missing values (geom_path).”
# plot without title
